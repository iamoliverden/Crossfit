# %% [markdown]
# **The Fringes of Fitness - 2020 Open Athletes**

# %% [markdown]
# M.K. - Project - BrainStation

# %% [markdown]
# **EDA, data-wrangling steps:**
#
# -	load packages,
# -	load data,
# -	check if all the columns we expect to see are present,
# -	remove NaNs,
# -	verify data types,
# -	check for duplicates,
# -	visualize the findings,
# -	save and create a .csv file for further processing.

# %%
# packages 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # plotting
import seaborn as sns
import re

# %% [markdown]
# We will work from the Google Drive - if you work from the local machine, you may want to adjust the below commands to let the datasets load from your local drive.

# %%
# mount google drive and load data 

from google.colab import drive
drive.mount('/content/drive')

df_2020_opens_scores = pd.read_csv(r"/content/drive/MyDrive/The_Fringes_of_Fitness/CrossFit_Data_Sets_2019_2020/2020_opens_scores.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # EDA and Data Wrangling
#
# Let's see what the data set we deal with looks like.

# %%
df_2020_opens_scores
# Out:
#                     affiliate  ...    time
# 0        CrossFit Sunninghill  ...   584.0
# 1        CrossFit Sunninghill  ...     NaN
# 2        CrossFit Sunninghill  ...   506.0
# 3        CrossFit Sunninghill  ...  1038.0
# 4        CrossFit Sunninghill  ...   638.0
# ...                       ...  ...     ...
# 1967670       CrossFit Gympie  ...   900.0
# 1967671                   NaN  ...     NaN
# 1967672                   NaN  ...     NaN
# 1967673                   NaN  ...     NaN
# 1967674                   NaN  ...     NaN
#
# [1967675 rows x 13 columns]

# %% [markdown]
# Let's check for duplicates - none!

# %%
# show a sum of duplicated values 

df_2020_opens_scores.duplicated(keep=False).sum()
# Out:
# 0

# %% [markdown]
# Below, check if the info of the dataset and the data types. The data set contains 1,967,675 rows - quite impressive, isn't it?

# %%
df_2020_opens_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1967675 entries, 0 to 1967674
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   affiliate        object
#  1   breakdown        object
#  2   competitorid     int64
#  3   division         object
#  4   is_scaled        int64
#  5   judge            object
#  6   ordinal          int64
#  7   rank             int64
#  8   scaled           int64
#  9   score            int64
#  10  scoredisplay     object
#  11  scoreidentifier  object
#  12  time             float64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 195.2+ MB

# %% [markdown]
# The below schema will be used to ensure that all the columns that we expect to have are indeed present.

# %%
# expected schema - df_2020_opens_scores

schema_exp_df_2020_opens_scores = {'ordinal': np.int64, 'breakdown': object,
                                  'rank': np.int64,
                                  'scoredisplay': np.int64,
                                  'time': np.int64,
                                  'rank': np.int64,
                                  'competitorid': np.int64,
                                  'scoreidentifier': object,
                                  'is_scaled': np.int64,
                                  'affiliate': object,
                                  'division': object,
                                  'judge': object,
                                  'score': np.int64}

# %% [markdown]
# Create a function to run the check of the schema.

# %%
# check columns

def schema_checker(df_2020_opens_scores, schema_exp_df_2020_opens_scores):
    for i in schema_exp_df_2020_opens_scores:
        if i not in df_2020_opens_scores.columns:
            print(f'"{i}" not found in dataset.')
            
        else:
            print(f'"{i}" is found.')

# %% [markdown]
# Print the result of the check and see if any discrepancies are discovered.

# %%
print(schema_checker(df_2020_opens_scores, schema_exp_df_2020_opens_scores))
# Out:
# "ordinal" is found.
# "breakdown" is found.
# "rank" is found.
# "scoredisplay" is found.
# "time" is found.
# "competitorid" is found.
# "scoreidentifier" is found.
# "is_scaled" is found.
# "affiliate" is found.
# "division" is found.
# "judge" is found.
# "score" is found.
# None

# %% [markdown]
# Create a visual to check for the missing values - they are present in many columns - 'affiliate', 'breakdown', 'judge', 'scoredisplay', 'scoreidentifier', 'time'.

# %%
# plot the missing data points 

fig, ax = plt.subplots(figsize=(12,8))
sns.heatmap(df_2020_opens_scores.isnull(), cbar=False, cmap="magma")
plt.show()

# %% [markdown]
# Let's create a function that formally checks for NaNs in the data set.

# %%
# check nans

def nan_checker(df_2020_opens_scores): 

    summary = {}
    # are there any nan values?
    any_nans = df_2020_opens_scores.isna().any().any()
    
    summary['NaNs Exist'] = any_nans
    
    # how many?
    n_nans = df_2020_opens_scores.isna().sum().sum()
    summary['NaN Count'] = n_nans
    
    # which variables do they come from
    nan_column_series = df_2020_opens_scores.isna().sum()
    nan_column_names = list(nan_column_series[nan_column_series > 0].index)
    
    summary['NaN Containing Columns'] = nan_column_names
    
    
    # any variables with more than 50% of data missing?
    nan_column_percent = 100 * nan_column_series/df_2020_opens_scores.shape[0]
    nan_columns_with_more_than_50_pct = list(nan_column_percent[nan_column_percent > 50].index)
    
    summary['NaNs More Than 50%'] = nan_columns_with_more_than_50_pct
    
    #summary can be all the info about nans
    return(summary)

# %% [markdown]
# Print out the name of the columns in which the NaNs are present and count their numbers.

# %%
print(nan_checker(df_2020_opens_scores))
# Out:
# {'NaNs Exist': True, 'NaN Count': 2563964, 'NaN Containing Columns': ['affiliate', 'breakdown', 'judge', 'scoredisplay', 'scoreidentifier', 'time'], 'NaNs More Than 50%': []}

# %% [markdown]
# Let's deal with NaNs:
#  - add 'None' to the cells with missing values - 'affiliate', 'breakdown',  'judge', 'scoreidentifier' - the absence of this information is not making us lose any value,
#  - replace the missing time with 0 - it is not a timed discipline.

# %%
# fill in the missing values with none where we have no opportunity to impute any meaningful data 

df_2020_opens_scores[['affiliate', 'breakdown', 'judge', 'scoreidentifier' ]] = df_2020_opens_scores[['affiliate', 'breakdown', 'judge', 'scoreidentifier']].fillna('None') # filling the missing NaNs

# %% [markdown]
# Check what columns still contain missing values - scoredisplay and time.

# %%
print(nan_checker(df_2020_opens_scores)) # all NaNs have been thus cleansed
# Out:
# {'NaNs Exist': True, 'NaN Count': 1038368, 'NaN Containing Columns': ['scoredisplay', 'time'], 'NaNs More Than 50%': []}

# %% [markdown]
# Fill in the time with 0.

# %%
# replace NaNs with zeros - the rest is the time in seconds 

df_2020_opens_scores['time'] = df_2020_opens_scores['time'].fillna(0)

# %% [markdown]
# Check what remains with missing values - scoredisplay.

# %%
print(nan_checker(df_2020_opens_scores))
# Out:
# {'NaNs Exist': True, 'NaN Count': 349102, 'NaN Containing Columns': ['scoredisplay'], 'NaNs More Than 50%': []}

# %% [markdown]
# Let's remove different words and non-int formats in the cells in the column 'scoredisplay'.

# %%
# eliminate time and other items that don't belong from the scoredisplay column

df_2020_opens_scores['scoredisplay']  = df_2020_opens_scores['scoredisplay'].str.replace(r"^(([0-1]?[0-9])|([2][0-3])):([0-5]?[0-9])(:([0-5]?[0-9]))?$",'0')
df_2020_opens_scores['scoredisplay']  = df_2020_opens_scores['scoredisplay'].str.replace(" - s",'')
df_2020_opens_scores['scoredisplay']  = df_2020_opens_scores['scoredisplay'].str.replace(r"^(([0-1]?[0-9])|([2][0-3])):([0-5]?[0-9][0-9])(:([0-5]?[0-9]))?$",'0')
df_2020_opens_scores['scoredisplay']  = df_2020_opens_scores['scoredisplay'].str.replace(" reps0",'')
df_2020_opens_scores['scoredisplay']  = df_2020_opens_scores['scoredisplay'].str.replace(" reps",'')

# %% [markdown]
# Replace the missing values in that column with 0 because it is not supposed to contain a value at all - it must be a timed discipline.

# %%
# eliminate nans

df_2020_opens_scores['scoredisplay'] = df_2020_opens_scores['scoredisplay'].fillna(0)

# %% [markdown]
# Check if any missing values remain - none!

# %%
print(nan_checker(df_2020_opens_scores)) # all nans are gone - bye honey!
# Out:
# {'NaNs Exist': False, 'NaN Count': 0, 'NaN Containing Columns': [], 'NaNs More Than 50%': []}

# %% [markdown]
# Let's reset the index to make sure that all the lines are in good order.

# %%
# reset index 

df_2020_opens_scores = df_2020_opens_scores.reset_index(drop=True)

# %% [markdown]
# Create a data-type checker function.

# %%
# checker of data types in columns

def dtype_checker(df_2020_opens_scores, schema_exp_df_2020_opens_scores):
    for column,dtype in schema_exp_df_2020_opens_scores.items():
        if column in df_2020_opens_scores.columns:
            if df_2020_opens_scores[column].dtype != dtype:
                print(f'"{column}" does not match dtype "{dtype}"')
           # column doesn't match the expected data type
        else:
            print(f'{column} matches the expected data type.')

# %% [markdown]
# Some data types mismatch - scoredisplay and time.

# %%
# the mistmatched datatypes after the first iteration - that indicates that some data points are not homogenic 

dtype_checker(df_2020_opens_scores, schema_exp_df_2020_opens_scores)
# Out:
# "scoredisplay" does not match dtype "<class 'numpy.int64'>"
# "time" does not match dtype "<class 'numpy.int64'>"

# %% [markdown]
# Let's correct the data type for scoredisplay - it should be integer.

# %%
# fix scoreplay data type

df_2020_opens_scores['scoredisplay'] = pd.Series(df_2020_opens_scores['scoredisplay'], dtype="int64") #successful

# %% [markdown]
# Let's correct the data type for time - it should be integer.

# %%
# fix time data type

df_2020_opens_scores['time'] = pd.Series(df_2020_opens_scores['time'], dtype="int64")#successful

# %% [markdown]
# ## Univariate analysis
#
# To perform the analysis, let's identify the columns that contain numerical and categorical variables.

# %%
# variables 

variables_check = ['affiliate',
                   'breakdown',
                   'competitorid',
                   'division',
                   'is_scaled',
                   'judge',
                   'ordinal',
                   'rank',
                   'scaled',
                   'score',
                   'scoredisplay',
                   'scoreidentifier',
                   'time']

# %% [markdown]
# Earlier, we decided that we will only analyze the men and women divisions. To achieve this goal, we shall create a data frame containing only these two divisions.

# %%
# create a df containing the data for the two largest divisions

df_2020_opens_scores_men_women = df_2020_opens_scores[(df_2020_opens_scores['division'] == 'Men') | (df_2020_opens_scores['division'] == 'Women')]

# %% [markdown]
# Let's examine how the newly created data frame looks like.

# %%
df_2020_opens_scores_men_women
# Out:
#                     affiliate  ... time
# 148635       CrossFit Nanaimo  ...  518
# 148636    CrossFit Soul Miami  ...    0
# 148637       CrossFit Nanaimo  ...  389
# 148638       CrossFit Nanaimo  ...  989
# 148639   CrossFit New England  ...  609
# ...                       ...  ...  ...
# 1967670       CrossFit Gympie  ...  900
# 1967671                  None  ...    0
# 1967672                  None  ...    0
# 1967673                  None  ...    0
# 1967674                  None  ...    0
#
# [1298115 rows x 13 columns]

# %% [markdown]
# Let's review the distribution of 'score' among men and women. From the visual examination below, it becomes evident that the column has not meaning, and the data in it is corrupt. We shall discard it, as we cannot identify ways to correct it. Thankfully, we seem not to need that data because we shall not use the data that we don't have before the competition begins, and the score seems to not pass this test (as it is unavailable before the competition begins - and cannot be used for our business case). We would not be able to build a working model based on such a piece of data.

# %%
# plot affiliate for men and women - for non-scaled 

col_val_counts = df_2020_opens_scores_men_women[df_2020_opens_scores_men_women['is_scaled'] == 0]['score'].value_counts()
    
plt.figure(figsize=(12,8))
sns.violinplot(y='division', x='score', data=df_2020_opens_scores_men_women, orient='h', scale='count', trim=True)
plt.ylabel("division")
plt.title('The score distribution for men and women doing non-scaled workouts')
plt.show()

# %% [markdown]
# Let's analyze the distribution of the scoredisplay column. The only thing we can tell from this distribution is that the shape of the distribution is similar for men and women. The rest - such as the predictive power that we might extract from this data - we wouldn't be able to judge in advance of modeling.

# %%
# plot scoredisplay for men and women

col_val_counts = df_2020_opens_scores_men_women[df_2020_opens_scores_men_women['is_scaled'] == 0]['scoredisplay'].value_counts()
    
plt.figure(figsize=(12,8))
sns.violinplot(y='division', x='scoredisplay', data=df_2020_opens_scores_men_women, orient='h', scale='count', trim=True)
plt.ylabel("division")
plt.title('The scoredisplay distribution for men and women doing non-scaled workouts')
plt.show()

# %% [markdown]
# The distribution of time also seems to be similar for men and women, but there is very little variance in this data, so it might potentially cause problems to modeling. We will know this later when we begin the modeling stage.

# %%
# plot time for men and women

col_val_counts = df_2020_opens_scores_men_women[df_2020_opens_scores_men_women['is_scaled'] == 0]['time'].value_counts()
    
plt.figure(figsize=(12,8))
sns.violinplot(y='division', x='scoredisplay', data=df_2020_opens_scores_men_women, orient='h', scale='count', trim=True)
plt.ylabel("division")
plt.title('The time distribution for men and women doing non-scaled workouts')
plt.show()

# %% [markdown]
# The distribution of ranks across the disciplines shows only that many competitors do not make it through till the end of the open competition - many drop out. As it is seen in the visual below, the distribution of ranks among the of the competitors naturally shrinks as the number of competitors becomes smaller. There is little use in this info, but we could use this idea and the data from 2019 as a predictor of the athletes' performance in the future years and for feature engineering, potentially.

# %%
sns.scatterplot(data = df_2020_opens_scores, x = "rank", y = "ordinal").set_title('The Distribution of ranks')
# Out:
# Text(0.5, 1.0, 'The Distribution of ranks')

# %% [markdown]
# Let's examine the info again - all is according to our expectations. Perfect!

# %%
df_2020_opens_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1967675 entries, 0 to 1967674
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   affiliate        object
#  1   breakdown        object
#  2   competitorid     int64
#  3   division         object
#  4   is_scaled        int64
#  5   judge            object
#  6   ordinal          int64
#  7   rank             int64
#  8   scaled           int64
#  9   score            int64
#  10  scoredisplay     int64
#  11  scoreidentifier  object
#  12  time             int64
# dtypes: int64(8), object(5)
# memory usage: 195.2+ MB

# %% [markdown]
# Let's save the data.
#
# At this point, we have retained most of the data and only discarded a few columns - not all of the data will be used in the future for modeling. But we are hesitant to drop columns, just in case we need to analyze them further and potentially use them in any feature engineering.

# %%
#examine the results 

df_2020_opens_scores
# Out:
#                     affiliate  ...  time
# 0        CrossFit Sunninghill  ...   584
# 1        CrossFit Sunninghill  ...     0
# 2        CrossFit Sunninghill  ...   506
# 3        CrossFit Sunninghill  ...  1038
# 4        CrossFit Sunninghill  ...   638
# ...                       ...  ...   ...
# 1967670       CrossFit Gympie  ...   900
# 1967671                  None  ...     0
# 1967672                  None  ...     0
# 1967673                  None  ...     0
# 1967674                  None  ...     0
#
# [1967675 rows x 13 columns]

# %%
#df_2020_opens_scores.to_csv('df_2020_opens_scores_final.csv', index=False)
